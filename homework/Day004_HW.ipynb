# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11624249877","type":"PushEvent","actor":{"id":59452115,"login":"larends","display_login":"larends","gravatar_id":"","url":"https://api.github.com/users/larends","avatar_url":"https://avatars.githubusercontent.com/u/59452115?"},"repo":{"id":243385519,"name":"larends/single-variable-regression-lab-data-science-intro-000","url":"https://api.github.com/repos/larends/single-variable-regression-lab-data-science-intro-000"},"payload":{"push_id":4689359199,"size":1,"distinct_size":1,"ref":"refs/heads/wip","head":"41a79e8df471170c4e5ec299abc69af328a5b636","before":"2412d9c3bc8624f11dac8f51e2878f1fcdf78e82","commits":[{"sha":"41a79e8df471170c4e5ec299abc69af328a5b636","author":{"email":"lisa@actionpotentialwellness.com","name":"Lisa Arends"},"message":"Automatically backed up by Learn","distinct":true,"url":"https://api.github.com/repos/larends/single-variable-regression-lab-data-science-intro-000/commits/41a79e8df471170c4e5ec299abc69af328a5b636"}]},"public":true,"created_at":"2020-02-27T10:25:43Z"},{"id":"11624249882","type":"CreateEvent","actor":{"id":10810283,"login":"direwolf-github","display_login":"direwolf-github","gravatar_id":"","url":"https://api.github.com/users/direwolf-github","avatar_url":"https://avatars.githubusercontent.com/u/10810283?"},"repo":{"id":243491810,"name":"direwolf-github/ephemeral-ci-1f45c899","url":"https://api.github.com/repos/direwolf-github/ephemeral-ci-1f45c899"},"payload":{"ref":"master","ref_type":"branch","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2020-02-27T10:25:43Z"},{"id":"11624249878","type":"PullRequestEvent","actor":{"id":57138795,"login":"aoneko25","display_login":"aoneko25","gravatar_id":"","url":"https://api.github.com/users/aoneko25","avatar_url":"https://avatars.githubusercontent.com/u/57138795?"},"repo":{"id":235715696,"name":"delfin378/freemarket_sample_61b","url":"https://api.github.com/repos/delfin378/freemarket_sample_61b"},"payload":{"action":"opened","number":11,"pull_request":{"url":"https://api.github.com/repos/delfin378/freemarket_sample_61b/pulls/11","id":380756466,"node_id":"MDExOlB1bGxSZXF1ZXN0MzgwNzU2NDY2","html_url":"https://github.com/delfin378/freemarket_sample_61b/pull/11","diff_url":"https://github.com/delfin378/freemarket_sample_61b/pull/11.diff","patch_url":"https://github.com/delfin378/freemarket_sample_61b/pull/11.patch","issue_url":"https://api.github.com/repos/delfin378/freemarket_sample_61b/issues/11","number":11,"state":"open","locked":false,"title":"[WIP]マークアップ\u3000プロフィール画面作成","user":{"login":"aoneko25","id":57138795,"node_id":"MDQ6VXNlcjU3MTM4Nzk1","avatar_url":"https://avatars3.githubusercontent.com/u/57138795?v=4","gravatar_id":"","url":"https://api.github.com/users/aoneko25","html_url":"https://github.com/aoneko25","followers_url":"https://api.github.com/users/aoneko25/followers","following_url":"https://api.github.com/users/aoneko25/following{/other_user}","gists_url":"https://api.github.com/users/aoneko25/gists{/gist_id}","starred_url":"https://api.github.com/users/aoneko25/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/aoneko25/subscriptions","organizations_url":"https://api.github.com/users/aoneko25/orgs","repos_url":"https://api.github.com/users/aoneko25/repos","events_url":"https://api.github.com/users/aoneko25/events{/privacy}","received_events_url":"https://api.github.com/users/aoneko25/received_events","type":"User","site_admin":false},"body":"#What\\r\\nユーザープロフィール画面作成。\\r\\n\\r\\n#Why\\r\\nフリマアプリにユーザープロフィール作成、編集機能を付ける為。\\r\\nクレジットと同じ方法でheader、footer、cameraをレンダーさせて完成させる。\\r\\n\\r\\nhttps://i.gyazo.com/c05fec5926d5e6a3c4cd6fbac96758f1.png\\r\\nhttps://i.gyazo.com/b248d68ea19a313211bcf297083bff72.png\\r\\n\\r\\n","created_at":"2020-02-27T10:25:43Z","updated_at":"2020-02-27T10:25:43Z","closed_at":null,"merged_at":null,"merge_commit_sha":null,"assignee":null,"assignees":[],"requested_reviewers":[],"requested_teams":[],"labels":[],"milestone":null,"commits_url":"http ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '11624237507',
#   'type': 'PushEvent',
#   'actor': {'id': 60560292,
#    'login': 'YYiiEt',
#    'display_login': 'YYiiEt',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/YYiiEt',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60560292?'},
#   'repo': {'id': 243464121,
#    'name': 'YYiiEt/raspberry-offical-openwrt-patch',
#    'url': 'https://api.github.com/repos/YYiiEt/raspberry-offical-openwrt-patch'},
#   'payload': {'push_id': 4689352515,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd71f909a85e21a286458e9b43db96a5840e85bbc',
#    'before': '785f2b289ba8ecf4c4339f0b4b0064de6ce79b5d',
#    'commits': [{'sha': 'd71f909a85e21a286458e9b43db96a5840e85bbc',
#      'author': {'email': '60560292+YYiiEt@users.noreply.github.com',
#       'name': 'YYiiEt'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/YYiiEt/raspberry-offical-openwrt-patch/commits/d71f909a85e21a286458e9b43db96a5840e85bbc'}]},
#   'public': True,
#   'created_at': '2020-02-27T10:24:23Z'},
#  {'id': '11624237511',
#   'type': 'WatchEvent',
#   'actor': {'id': 456499,
#    'login': 'rocboronat',
#    'display_login': 'rocboronat',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rocboronat',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/456499?'},
#   'repo': {'id': 132543051,
#    'name': 'aqwert/flutter_platform_widgets',
#    'url': 'https://api.github.com/repos/aqwert/flutter_platform_widgets'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-02-27T10:24:23Z'},
#  {'id': '11624237508',
#   'type': 'PublicEvent',
#   'actor': {'id': 43416619,
#    'login': 'Penyucian',
#    'display_login': 'Penyucian',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Penyucian',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43416619?'},
#   'repo': {'id': 243474285,
#    'name': 'Penyucian/1',
#    'url': 'https://api.github.com/repos/Penyucian/1'},
#   'payload': {},
#   'public': True,
#   'created_at': '2020-02-27T10:24:23Z'},
#  {'id': '11624237504',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 28656273,
#    'login': 'build-travis-ci',
#    'display_login': 'build-travis-ci',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/build-travis-ci',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28656273?'},
#   'repo': {'id': 79343946,
#    'name': 'Talend/ui',
#    'url': 'https://api.github.com/repos/Talend/ui'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/Talend/ui/issues/2672',
#     'repository_url': 'https://api.github.com/repos/Talend/ui',
#     'labels_url': 'https://api.github.com/repos/Talend/ui/issues/2672/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/Talend/ui/issues/2672/comments',
#     'events_url': 'https://api.github.com/repos/Talend/ui/issues/2672/events',
#     'html_url': 'https://github.com/Talend/ui/pull/2672',
#     'id': 571955219,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzgwNzQ0MDcx',
#     'number': 2672,
#     'title': 'fix(ResourceList): fix style',
#     'user': {'login': 'jare-talend',
#      'id': 20772261,
#      'node_id': 'MDQ6VXNlcjIwNzcyMjYx',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/20772261?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jare-talend',
#      'html_url': 'https://github.com/jare-talend',
#      'followers_url': 'https://api.github.com/users/jare-talend/followers',
#      'following_url': 'https://api.github.com/users/jare-talend/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jare-talend/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jare-talend/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jare-talend/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jare-talend/orgs',
#      'repos_url': 'https://api.github.com/users/jare-talend/repos',
#      'events_url': 'https://api.github.com/users/jare-talend/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jare-talend/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 520978449,
#       'node_id': 'MDU6TGFiZWw1MjA5Nzg0NDk=',
#       'url': 'https://api.github.com/repos/Talend/ui/labels/bug',
#       'name': 'bug',
#       'color': 'ee0701',
#       'default': True,
#       'description': None},
#      {'id': 530809343,
#       'node_id': 'MDU6TGFiZWw1MzA4MDkzNDM=',
#       'url': 'https://api.github.com/repos/Talend/ui/labels/easy%20review',
#       'name': 'easy review',
#       'color': 'ff69b4',
#       'default': False,
#       'description': None},
#      {'id': 521021722,
#       'node_id': 'MDU6TGFiZWw1MjEwMjE3MjI=',
#       'url': 'https://api.github.com/repos/Talend/ui/labels/need%20review',
#       'name': 'need review',
#       'color': 'fbca04',
#       'default': False,
#       'description': None}],
#     'state': 'open',
#     'locked': False,
#     'assignee': {'login': 'jare-talend',
#      'id': 20772261,
#      'node_id': 'MDQ6VXNlcjIwNzcyMjYx',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/20772261?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jare-talend',
#      'html_url': 'https://github.com/jare-talend',
#      'followers_url': 'https://api.github.com/users/jare-talend/followers',
#      'following_url': 'https://api.github.com/users/jare-talend/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jare-talend/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jare-talend/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jare-talend/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jare-talend/orgs',
#      'repos_url': 'https://api.github.com/users/jare-talend/repos',
#      'events_url': 'https://api.github.com/users/jare-talend/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jare-talend/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'jare-talend',
#       'id': 20772261,
#       'node_id': 'MDQ6VXNlcjIwNzcyMjYx',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/20772261?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/jare-talend',
#       'html_url': 'https://github.com/jare-talend',
#       'followers_url': 'https://api.github.com/users/jare-talend/followers',
#       'following_url': 'https://api.github.com/users/jare-talend/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jare-talend/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/jare-talend/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jare-talend/subscriptions',
#       'organizations_url': 'https://api.github.com/users/jare-talend/orgs',
#       'repos_url': 'https://api.github.com/users/jare-talend/repos',
#       'events_url': 'https://api.github.com/users/jare-talend/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/jare-talend/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2020-02-27T09:59:55Z',
#     'updated_at': '2020-02-27T10:24:23Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'pull_request': {'url': 'https://api.github.com/repos/Talend/ui/pulls/2672',
#      'html_url': 'https://github.com/Talend/ui/pull/2672',
#      'diff_url': 'https://github.com/Talend/ui/pull/2672.diff',
#      'patch_url': 'https://github.com/Talend/ui/pull/2672.patch'},
#     'body': '**What is the problem this PR is trying to solve?**\r\nfix style on the resourcepicker\r\nhttps://company-57688.frontify.com/document/92132#/ui-controls/popover\r\n\r\n**What is the chosen solution to this problem?**\r\n\r\n**Please check if the PR fulfills these requirements**\r\n\r\n* [x] The PR commit message follows our [guidelines](https://github.com/talend/tools/blob/master/tools-root-github/CONTRIBUTING.md)\r\n* [X] Tests for the changes have been added (for bug fixes / features) And [non reg](./screenshots.md) done before need review\r\n* [ ] Docs have been added / updated (for bug fixes / features)\r\n* [ ] Related design / discussions / pages (not in jira), if any, are all linked or available in the PR\r\n\r\n<!-- You can add more checkboxes here -->\r\n\r\n**[ ] This PR introduces a breaking change**\r\n\r\n<!-- if the PR introduces a breaking change, add the description here. So when you merge this PR, add this description into the [breaking change wiki](https://github.com/Talend/ui/wiki/BREAKING-CHANGE) in the next version -->\r\n\r\n<!-- **Original Template** -->\r\n\r\n<!-- https://github.com/Talend/tools/blob/master/tools-root-github/.github/PULL_REQUEST_TEMPLATE.md -->\r\n'},
#    'comment': {'url': 'https://api.github.com/repos/Talend/ui/issues/comments/591894958',
#     'html_url': 'https://github.com/Talend/ui/pull/2672#issuecomment-591894958',
#     'issue_url': 'https://api.github.com/repos/Talend/ui/issues/2672',
#     'id': 591894958,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU5MTg5NDk1OA==',
#     'user': {'login': 'build-travis-ci',
#      'id': 28656273,
#      'node_id': 'MDQ6VXNlcjI4NjU2Mjcz',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/28656273?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/build-travis-ci',
#      'html_url': 'https://github.com/build-travis-ci',
#      'followers_url': 'https://api.github.com/users/build-travis-ci/followers',
#      'following_url': 'https://api.github.com/users/build-travis-ci/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/build-travis-ci/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/build-travis-ci/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/build-travis-ci/subscriptions',
#      'organizations_url': 'https://api.github.com/users/build-travis-ci/orgs',
#      'repos_url': 'https://api.github.com/users/build-travis-ci/repos',
#      'events_url': 'https://api.github.com/users/build-travis-ci/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/build-travis-ci/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-02-27T10:24:23Z',
#     'updated_at': '2020-02-27T10:24:23Z',
#     'author_association': 'COLLABORATOR',
#     'body': ':octocat: [Demo is available here](http://2672.talend.surge.sh) '}},
#   'public': True,
#   'created_at': '2020-02-27T10:24:23Z',
#   'org': {'id': 459687,
#    'login': 'Talend',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Talend',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/459687?'}},
#  {'id': '11624237502',
#   'type': 'CreateEvent',
#   'actor': {'id': 4725410,
#    'login': 'sashulyak',
#    'display_login': 'sashulyak',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sashulyak',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4725410?'},
#   'repo': {'id': 243491530,
#    'name': 'ivi-ru/video-scene-detection',
#    'url': 'https://api.github.com/repos/ivi-ru/video-scene-detection'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-27T10:24:23Z',
#   'org': {'id': 44371777,
#    'login': 'ivi-ru',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ivi-ru',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44371777?'}},
#  {'id': '11624237490',
#   'type': 'PushEvent',
#   'actor': {'id': 10155713,
#    'login': 'eperott',
#    'display_login': 'eperott',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eperott',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10155713?'},
#   'repo': {'id': 146795815,
#    'name': 'eperott/ecaudit',
#    'url': 'https://api.github.com/repos/eperott/ecaudit'},
#   'payload': {'push_id': 4689352509,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/bump_cassandra_30',
#    'head': '8755042ace50aef17c8503bca92abe470a951e11',
#    'before': '2c7ff13c245360c8523579d18ca4191ca0db7132',
#    'commits': [{'sha': '8755042ace50aef17c8503bca92abe470a951e11',
#      'author': {'email': 'per.otterstrom@ericsson.com',
#       'name': 'Per Otterström'},
#      'message': 'Fix review comments',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eperott/ecaudit/commits/8755042ace50aef17c8503bca92abe470a951e11'}]},
#   'public': True,
#   'created_at': '2020-02-27T10:24:23Z'},
#  {'id': '11624237488',
#   'type': 'PushEvent',
#   'actor': {'id': 14833035,
#    'login': 'bob0627',
#    'display_login': 'bob0627',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bob0627',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14833035?'},
#   'repo': {'id': 242912631,
#    'name': 'bob0627/bob0627.github.io',
#    'url': 'https://api.github.com/repos/bob0627/bob0627.github.io'},
#   'payload': {'push_id': 4689352510,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '298ab4dc3ecb14d8435e89c27e230f430f654495',
#    'before': '640b8fdd5f5626842795cc54d23c6b4868d17ee5',
#    'commits': [{'sha': '298ab4dc3ecb14d8435e89c27e230f430f654495',
#      'author': {'email': '', 'name': 'bob0627'},
#      'message': 'update from gridea: 2020-02-27 18:24:16',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bob0627/bob0627.github.io/commits/298ab4dc3ecb14d8435e89c27e230f430f654495'}]},
#   'public': True,
#   'created_at': '2020-02-27T10:24:23Z'},
#  {'id': '11624237475',
#   'type': 'PushEvent',
#   'actor': {'id': 28230839,
#    'login': 'virajvjoshi',
#    'display_login': 'virajvjoshi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/virajvjoshi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28230839?'},
#   'repo': {'id': 243479030,
#    'name': 'virajvjoshi/data4drink',
#    'url': 'https://api.github.com/repos/virajvjoshi/data4drink'},
#   'payload': {'push_id': 4689352490,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '3b11d0be8178840677df026e4ef1d299e205c94d',
#    'before': '73e12ddc30b2390975fa422f18725a8a31950a98',
#    'commits': [{'sha': '3b11d0be8178840677df026e4ef1d299e205c94d',
#      'author': {'email': 'viraj.joshi@network.rca.ac.uk',
#       'name': 'Viraj Joshi'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/virajvjoshi/data4drink/commits/3b11d0be8178840677df026e4ef1d299e205c94d'}]},
#   'public': True,
#   'created_at': '2020-02-27T10:24:23Z'},
#  {'id': '11624237484',
#   'type': 'PushEvent',
#   'actor': {'id': 28378961,
#    'login': 'shianr',
#    'display_login': 'shianr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shianr',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28378961?'},
#   'repo': {'id': 243452299,
#    'name': 'shianr/test0227',
#    'url': 'https://api.github.com/repos/shianr/test0227'},
#   'payload': {'push_id': 4689352506,
#    'size': 6,
#    'distinct_size': 6,
#    'ref': 'refs/heads/master',
#    'head': '569a2400f002bac460db801ba7cc652aa946c166',
#    'before': 'e4d698a4373969d68fa483999eed7f8dc95a44a7',
#    'commits': [{'sha': '57b9e58c3d174b53e3d0b1fba190a304885938dc',
#      'author': {'email': '56335241+sartest@users.noreply.github.com',
#       'name': 'sartest'},
#      'message': '2222',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shianr/test0227/commits/57b9e58c3d174b53e3d0b1fba190a304885938dc'},
#     {'sha': 'fb2d1a4a3b252f647a7b96b1465c0585c7fc22cc',
#      'author': {'email': '56335241+sartest@users.noreply.github.com',
#       'name': 'sartest'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shianr/test0227/commits/fb2d1a4a3b252f647a7b96b1465c0585c7fc22cc'},
#     {'sha': 'd277b16b13c7abf13670dcfcf4d60f74a04ba46d',
#      'author': {'email': '56335241+sartest@users.noreply.github.com',
#       'name': 'sartest'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shianr/test0227/commits/d277b16b13c7abf13670dcfcf4d60f74a04ba46d'},
#     {'sha': 'f1fecb76867214c9ce35cd655c3b8e82deb64acf',
#      'author': {'email': '56335241+sartest@users.noreply.github.com',
#       'name': 'sartest'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shianr/test0227/commits/f1fecb76867214c9ce35cd655c3b8e82deb64acf'},
#     {'sha': '03133af2544309fe1afddb2350b7e5242bd02106',
#      'author': {'email': '56335241+sartest@users.noreply.github.com',
#       'name': 'sartest'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shianr/test0227/commits/03133af2544309fe1afddb2350b7e5242bd02106'},
#     {'sha': '569a2400f002bac460db801ba7cc652aa946c166',
#      'author': {'email': 'anran221@163.com', 'name': 'shianr'},
#      'message': 'Merge pull request #2 from sartest/master\n\n2222',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shianr/test0227/commits/569a2400f002bac460db801ba7cc652aa946c166'}]},
#   'public': True,
#   'created_at': '2020-02-27T10:24:23Z'},
#  {'id': '11624237478',
#   'type': 'PushEvent',
#   'actor': {'id': 25722093,
#    'login': 'pg598595',
#    'display_login': 'pg598595',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pg598595',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25722093?'},
#   'repo': {'id': 242962463,
#    'name': 'pg598595/ScopedStorage',
#    'url': 'https://api.github.com/repos/pg598595/ScopedStorage'},
#   'payload': {'push_id': 4689352487,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '43b7dd5c065460d5ea7ac68a4588e912d7b0269a',
#    'before': 'c20e983a07b96bd34d9301be202811886061c9dd',
#    'commits': [{'sha': '43b7dd5c065460d5ea7ac68a4588e912d7b0269a',
#      'author': {'email': 'pg598595@gmail.com', 'name': 'Priyanka Gupta'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/pg598595/ScopedStorage/commits/43b7dd5c065460d5ea7ac68a4588e912d7b0269a'}]},
#   'public': True,
#   'created_at': '2020-02-27T10:24:23Z'},
#  {'id': '11624237471',
#   'type': 'PushEvent',
#   'actor': {'id': 50266731,
#    'login': 'VDoring',
#    'display_login': 'VDoring',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/VDoring',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50266731?'},
#   'repo': {'id': 219484803,
#    'name': 'VDoring/CPP-My-Study-Functions',
#    'url': 'https://api.github.com/repos/VDoring/CPP-My-Study-Functions'},
#   'payload': {'push_id': 4689352483,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '29f434b8d42b8d38f2ac0227b06a697a2457b7ee',
#    'before': '43bcb03209c3da4e4cc8d2b42b7ce6f508d9b5a9',
#    'commits': [{'sha': '29f434b8d42b8d38f2ac0227b06a697a2457b7ee',
#      'author': {'email': 'hojun.dev@gmail.com', 'name': 'Doring'},
#      'message': '콘솔창에 출력하기(cout, cin, endl)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/VDoring/CPP-My-Study-Functions/commits/29f434b8d42b8d38f2ac0227b06a697a2457b7ee'}]},
#   'public': True,
#   'created_at': '2020-02-27T10:24:23Z'},
#  {'id': '11624237464',
#   'type': 'CreateEvent',
#   'actor': {'id': 23716400,
#    'login': 'birungiviola22',
#    'display_login': 'birungiviola22',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/birungiviola22',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23716400?'},
#   'repo': {'id': 243491539,
#    'name': 'birungiviola22/breeze',
#    'url': 'https://api.github.com/repos/birungiviola22/breeze'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'meditation site',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-27T10:24:23Z'},
#  {'id': '11624237453',
#   'type': 'PushEvent',
#   'actor': {'id': 60396543,
#    'login': 'FaybenM',
#    'display_login': 'FaybenM',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/FaybenM',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60396543?'},
#   'repo': {'id': 237218463,
#    'name': 'FaybenM/FaybenM.github.io',
#    'url': 'https://api.github.com/repos/FaybenM/FaybenM.github.io'},
#   'payload': {'push_id': 4689352485,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6b750dc99ea987441ffbc70886f96660df43cc55',
#    'before': '650ca895dbf17004c720c8f5ecbdbb2e973f95ca',
#    'commits': [{'sha': '6b750dc99ea987441ffbc70886f96660df43cc55',
#      'author': {'email': 'puppy02468@gmail.com', 'name': 'F'},
#      'message': 'newer2',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/FaybenM/FaybenM.github.io/commits/6b750dc99ea987441ffbc70886f96660df43cc55'}]},
#   'public': True,
#   'created_at': '2020-02-27T10:24:23Z'},
#  {'id': '11624237454',
#   'type': 'PushEvent',
#   'actor': {'id': 42404280,
#    'login': 'MeasponeS',
#    'display_login': 'MeasponeS',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MeasponeS',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42404280?'},
#   'repo': {'id': 127852518,
#    'name': 'ZoranWong/pinehub-user',
#    'url': 'https://api.github.com/repos/ZoranWong/pinehub-user'},
#   'payload': {'push_id': 4689352486,
#    'size': 4,
#    'distinct_size': 4,
#    'ref': 'refs/heads/newIndex',
#    'head': 'e0507e1f037571f15ce08d61c76f51afadce5af0',
#    'before': '3bb0231c7659b30eaa6db856432ee070affeb251',
#    'commits': [{'sha': '671918e72bf1d24df0e5592e5dd4d8f0adda9339',
#      'author': {'email': '958183117@qq.com', 'name': 'MeasponeS'},
#      'message': 'coupon use',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ZoranWong/pinehub-user/commits/671918e72bf1d24df0e5592e5dd4d8f0adda9339'},
#     {'sha': '130fef3c55b5374fad2a3da86a45594ab980dc53',
#      'author': {'email': '958183117@qq.com', 'name': 'MeasponeS'},
#      'message': 'coupons',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ZoranWong/pinehub-user/commits/130fef3c55b5374fad2a3da86a45594ab980dc53'},
#     {'sha': '4116a41ecd670ee9f04c9d01d6dcc4a371c1417b',
#      'author': {'email': '958183117@qq.com', 'name': 'MeasponeS'},
#      'message': "Merge branch 'newIndex' of https://github.com/ZoranWong/pinehub-user into newIndex",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ZoranWong/pinehub-user/commits/4116a41ecd670ee9f04c9d01d6dcc4a371c1417b'},
#     {'sha': 'e0507e1f037571f15ce08d61c76f51afadce5af0',
#      'author': {'email': '958183117@qq.com', 'name': 'MeasponeS'},
#      'message': 'coupon use',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ZoranWong/pinehub-user/commits/e0507e1f037571f15ce08d61c76f51afadce5af0'}]},
#   'public': True,
#   'created_at': '2020-02-27T10:24:23Z'},
#  {'id': '11624237419',
#   'type': 'PushEvent',
#   'actor': {'id': 58770589,
#    'login': 'paulsimonandrews',
#    'display_login': 'paulsimonandrews',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/paulsimonandrews',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58770589?'},
#   'repo': {'id': 232119040,
#    'name': 'DEFRA/ffc-ce-payment-orchestrator',
#    'url': 'https://api.github.com/repos/DEFRA/ffc-ce-payment-orchestrator'},
#   'payload': {'push_id': 4689352471,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/psd-512-create-db',
#    'head': '83dca806f40c71ed3f85fe6e5e7e9fd40ca18633',
#    'before': '3344e951203714c1cde01b6b2d2269f50280e8c3',
#    'commits': [{'sha': '83dca806f40c71ed3f85fe6e5e7e9fd40ca18633',
#      'author': {'email': 'paul.andrews@defra.gov.uk', 'name': 'Paul Andrews'},
#      'message': 'test destroy sqs',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/DEFRA/ffc-ce-payment-orchestrator/commits/83dca806f40c71ed3f85fe6e5e7e9fd40ca18633'}]},
#   'public': True,
#   'created_at': '2020-02-27T10:24:23Z',
#   'org': {'id': 5528822,
#    'login': 'DEFRA',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/DEFRA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5528822?'}},
#  {'id': '11624237409',
#   'type': 'PushEvent',
#   'actor': {'id': 12747918,
#    'login': 'foroozan',
#    'display_login': 'foroozan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/foroozan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12747918?'},
#   'repo': {'id': 243395162,
#    'name': 'foroozan/Test',
#    'url': 'https://api.github.com/repos/foroozan/Test'},
#   'payload': {'push_id': 4689352454,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'cb9acbc84943c8ff80e66c444a2894963b6e6264',
#    'before': '1e8afedaa7b53276fb3504146b015622bc728811',
#    'commits': [{'sha': 'cb9acbc84943c8ff80e66c444a2894963b6e6264',
#      'author': {'email': 'foroozan@users.noreply.github.com',
#       'name': 'foroozan'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/foroozan/Test/commits/cb9acbc84943c8ff80e66c444a2894963b6e6264'}]},
#   'public': True,
#   'created_at': '2020-02-27T10:24:23Z'},
#  {'id': '11624237425',
#   'type': 'PushEvent',
#   'actor': {'id': 51737503,
#    'login': 'akshit61',
#    'display_login': 'akshit61',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/akshit61',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51737503?'},
#   'repo': {'id': 198820861,
#    'name': 'akshit61/ga-learner-dsmp-repo',
#    'url': 'https://api.github.com/repos/akshit61/ga-learner-dsmp-repo'},
#   'payload': {'push_id': 4689352468,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7a7b35d22a4403e2dc8a021c544c5f3a1a30ff82',
#    'before': '5751ffec5e9fdc31c1781812fb511e23c1101622',
#    'commits': [{'sha': '7a7b35d22a4403e2dc8a021c544c5f3a1a30ff82',
#      'author': {'email': 'akshit61@users.noreply.github.com',
#       'name': 'akshit61'},
#      'message': 'Code file created.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/akshit61/ga-learner-dsmp-repo/commits/7a7b35d22a4403e2dc8a021c544c5f3a1a30ff82'}]},
#   'public': True,
#   'created_at': '2020-02-27T10:24:23Z'},
#  {'id': '11624237430',
#   'type': 'PushEvent',
#   'actor': {'id': 39460800,
#    'login': 'Mockingjay1316',
#    'display_login': 'Mockingjay1316',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mockingjay1316',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39460800?'},
#   'repo': {'id': 241557100,
#    'name': 'Mockingjay1316/rCore-step-by-step',
#    'url': 'https://api.github.com/repos/Mockingjay1316/rCore-step-by-step'},
#   'payload': {'push_id': 4689352457,
#    'size': 7,
#    'distinct_size': 7,
#    'ref': 'refs/heads/master',
#    'head': '2a13bf798b3713f7f6960823d847f795128d5b75',
#    'before': 'f7cdd82c0d6f13e75ab89c21025a82416c4e9070',
#    'commits': [{'sha': '2817058d5b77bc103a1d0d11cfd072fd04a3a410',
#      'author': {'email': '965603699@qq.com', 'name': 'Cao Dingyuan'},
#      'message': 'IO functions for user.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Mockingjay1316/rCore-step-by-step/commits/2817058d5b77bc103a1d0d11cfd072fd04a3a410'},
#     {'sha': '2982d2c504634b14e747d06fc8348f0d7af78bd3',
#      'author': {'email': '965603699@qq.com', 'name': 'Cao Dingyuan'},
#      'message': 'User syscalls.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Mockingjay1316/rCore-step-by-step/commits/2982d2c504634b14e747d06fc8348f0d7af78bd3'},
#     {'sha': '6a8facdc9a35dc1102201f22d32c1d6a97cde063',
#      'author': {'email': '965603699@qq.com', 'name': 'Cao Dingyuan'},
#      'message': 'Language items.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Mockingjay1316/rCore-step-by-step/commits/6a8facdc9a35dc1102201f22d32c1d6a97cde063'},
#     {'sha': '0f05b60f961dd0a5a5efe9dc10f7773270cf841d',
#      'author': {'email': '965603699@qq.com', 'name': 'Cao Dingyuan'},
#      'message': 'lib files.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Mockingjay1316/rCore-step-by-step/commits/0f05b60f961dd0a5a5efe9dc10f7773270cf841d'},
#     {'sha': 'af93ca4605c8b9f802da71054add6f250de7b070',
#      'author': {'email': '965603699@qq.com', 'name': 'Cao Dingyuan'},
#      'message': 'User program template.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Mockingjay1316/rCore-step-by-step/commits/af93ca4605c8b9f802da71054add6f250de7b070'},
#     {'sha': '367299c0b27b65cb261008f95c53859e2856e484',
#      'author': {'email': '965603699@qq.com', 'name': 'Cao Dingyuan'},
#      'message': 'Hello world program',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Mockingjay1316/rCore-step-by-step/commits/367299c0b27b65cb261008f95c53859e2856e484'},
#     {'sha': '2a13bf798b3713f7f6960823d847f795128d5b75',
#      'author': {'email': '965603699@qq.com', 'name': 'Cao Dingyuan'},
#      'message': 'Rust files.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Mockingjay1316/rCore-step-by-step/commits/2a13bf798b3713f7f6960823d847f795128d5b75'}]},
#   'public': True,
#   'created_at': '2020-02-27T10:24:23Z'},
#  {'id': '11624237411',
#   'type': 'PushEvent',
#   'actor': {'id': 55698603,
#    'login': 'ac-93',
#    'display_login': 'ac-93',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ac-93',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55698603?'},
#   'repo': {'id': 210354015,
#    'name': 'ac-93/soft-actor-critic',
#    'url': 'https://api.github.com/repos/ac-93/soft-actor-critic'},
#   'payload': {'push_id': 4689352452,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8e7d08ad5cdb2dee7b24644fad61a18d49a2f6a8',
#    'before': '89d6bb4bb7618ebbbe2bda0deacd2ead58cb7cc6',
#    'commits': [{'sha': '8e7d08ad5cdb2dee7b24644fad61a18d49a2f6a8',
#      'author': {'email': '55698603+ac-93@users.noreply.github.com',
#       'name': 'ac-93'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ac-93/soft-actor-critic/commits/8e7d08ad5cdb2dee7b24644fad61a18d49a2f6a8'}]},
#   'public': True,
#   'created_at': '2020-02-27T10:24:23Z'},
#  {'id': '11624237415',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 36623372,
#    'login': 'Fezzzi',
#    'display_login': 'Fezzzi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Fezzzi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36623372?'},
#   'repo': {'id': 173714728,
#    'name': 'salsita/foosball-rating',
#    'url': 'https://api.github.com/repos/salsita/foosball-rating'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/salsita/foosball-rating/pulls/comments/385036295',
#     'pull_request_review_id': 365566063,
#     'id': 385036295,
#     'node_id': 'MDI0OlB1bGxSZXF1ZXN0UmV2aWV3Q29tbWVudDM4NTAzNjI5NQ==',
#     'diff_hunk': '@@ -0,0 +1,27 @@\n+import React from \'react\'\n+import { withRouter } from \'react-router-dom\'\n+import {\n+  TextSpan,\n+  ListItem,\n+  StyledLink,\n+} from \'../../../styles/blocks\'\n+import { createProfilePath } from \'../../const/routes\'\n+\n+const trophies = [\n+  require(\'../../../media/trophy-1.svg\'),\n+  require(\'../../../media/trophy-2.svg\'),\n+  require(\'../../../media/trophy-3.svg\'),\n+]\n+\n+const LeaderboardsRowComponent = ({ user, position, points }) => (\n+  <ListItem>\n+    <TextSpan align="left">{\n+      position > 3 ? (position + \'.\') : <img src={trophies[position - 1]} />\n+    }</TextSpan>\n+    <TextSpan textAlign="right">\n+      <StyledLink to={createProfilePath(user.id)}>{user.name} ({points})</StyledLink>\n+    </TextSpan>\n+  </ListItem>\n+)\n+\n+export const LeaderboardsRow = withRouter(LeaderboardsRowComponent)',
#     'path': 'frontend/src/app/components/Leaderboards/LeaderboardsRow.js',
#     'position': None,
#     'original_position': 27,
#     'commit_id': 'd7c17da31ec421acbb90f4a19ce22c34412cdf35',
#     'original_commit_id': '2f72a30b277488ad91223ad7a38db5c0a8e70fd5',
#     'user': {'login': 'Fezzzi',
#      'id': 36623372,
#      'node_id': 'MDQ6VXNlcjM2NjIzMzcy',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/36623372?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Fezzzi',
#      'html_url': 'https://github.com/Fezzzi',
#      'followers_url': 'https://api.github.com/users/Fezzzi/followers',
#      'following_url': 'https://api.github.com/users/Fezzzi/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Fezzzi/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Fezzzi/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Fezzzi/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Fezzzi/orgs',
#      'repos_url': 'https://api.github.com/users/Fezzzi/repos',
#      'events_url': 'https://api.github.com/users/Fezzzi/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Fezzzi/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Fixed [here](https://github.com/salsita/foosball-rating/pull/92/commits/d7c17da31ec421acbb90f4a19ce22c34412cdf35#diff-ccbac6f012a8b829dcf10aa31411e483) and [here](https://github.com/salsita/foosball-rating/pull/92/commits/d7c17da31ec421acbb90f4a19ce22c34412cdf35#diff-32d0948dd609721b4bda2c94363a08eb)',
#     'created_at': '2020-02-27T10:24:22Z',
#     'updated_at': '2020-02-27T10:24:22Z',
#     'html_url': 'https://github.com/salsita/foosball-rating/pull/92#discussion_r385036295',
#     'pull_request_url': 'https://api.github.com/repos/salsita/foosball-rating/pulls/92',
#     'author_association': 'COLLABORATOR',
#     '_links': {'self': {'href': 'https://api.github.com/repos/salsita/foosball-rating/pulls/comments/385036295'},
#      'html': {'href': 'https://github.com/salsita/foosball-rating/pull/92#discussion_r385036295'},
#      'pull_request': {'href': 'https://api.github.com/repos/salsita/foosball-rating/pulls/92'}},
#     'in_reply_to_id': 384403170},
#    'pull_request': {'url': 'https://api.github.com/repos/salsita/foosball-rating/pulls/92',
#     'id': 379464589,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0Mzc5NDY0NTg5',
#     'html_url': 'https://github.com/salsita/foosball-rating/pull/92',
#     'diff_url': 'https://github.com/salsita/foosball-rating/pull/92.diff',
#     'patch_url': 'https://github.com/salsita/foosball-rating/pull/92.patch',
#     'issue_url': 'https://api.github.com/repos/salsita/foosball-rating/issues/92',
#     'number': 92,
#     'state': 'open',
#     'locked': False,
#     'title': 'Issue 28 create leaderboards',
#     'user': {'login': 'Fezzzi',
#      'id': 36623372,
#      'node_id': 'MDQ6VXNlcjM2NjIzMzcy',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/36623372?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Fezzzi',
#      'html_url': 'https://github.com/Fezzzi',
#      'followers_url': 'https://api.github.com/users/Fezzzi/followers',
#      'following_url': 'https://api.github.com/users/Fezzzi/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Fezzzi/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Fezzzi/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Fezzzi/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Fezzzi/orgs',
#      'repos_url': 'https://api.github.com/users/Fezzzi/repos',
#      'events_url': 'https://api.github.com/users/Fezzzi/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Fezzzi/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2020-02-25T09:33:59Z',
#     'updated_at': '2020-02-27T10:24:22Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '96f16bbad76384c72f459c980680f1ef08d88cb4',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 1257537450,
#       'node_id': 'MDU6TGFiZWwxMjU3NTM3NDUw',
#       'url': 'https://api.github.com/repos/salsita/foosball-rating/labels/enhancement',
#       'name': 'enhancement',
#       'color': 'a2eeef',
#       'default': True,
#       'description': 'New feature or request'}],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/salsita/foosball-rating/pulls/92/commits',
#     'review_comments_url': 'https://api.github.com/repos/salsita/foosball-rating/pulls/92/comments',
#     'review_comment_url': 'https://api.github.com/repos/salsita/foosball-rating/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/salsita/foosball-rating/issues/92/comments',
#     'statuses_url': 'https://api.github.com/repos/salsita/foosball-rating/statuses/d7c17da31ec421acbb90f4a19ce22c34412cdf35',
#     'head': {'label': 'salsita:issue-28_create-leaderboards',
#      'ref': 'issue-28_create-leaderboards',
#      'sha': 'd7c17da31ec421acbb90f4a19ce22c34412cdf35',
#      'user': {'login': 'salsita',
#       'id': 1357845,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEzNTc4NDU=',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/1357845?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/salsita',
#       'html_url': 'https://github.com/salsita',
#       'followers_url': 'https://api.github.com/users/salsita/followers',
#       'following_url': 'https://api.github.com/users/salsita/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/salsita/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/salsita/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/salsita/subscriptions',
#       'organizations_url': 'https://api.github.com/users/salsita/orgs',
#       'repos_url': 'https://api.github.com/users/salsita/repos',
#       'events_url': 'https://api.github.com/users/salsita/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/salsita/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 173714728,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNzM3MTQ3Mjg=',
#       'name': 'foosball-rating',
#       'full_name': 'salsita/foosball-rating',
#       'private': False,
#       'owner': {'login': 'salsita',
#        'id': 1357845,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEzNTc4NDU=',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/1357845?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/salsita',
#        'html_url': 'https://github.com/salsita',
#        'followers_url': 'https://api.github.com/users/salsita/followers',
#        'following_url': 'https://api.github.com/users/salsita/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/salsita/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/salsita/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/salsita/subscriptions',
#        'organizations_url': 'https://api.github.com/users/salsita/orgs',
#        'repos_url': 'https://api.github.com/users/salsita/repos',
#        'events_url': 'https://api.github.com/users/salsita/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/salsita/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/salsita/foosball-rating',
#       'description': "Keeps track of foosball player's rating based on augmented chess elo rating",
#       'fork': False,
#       'url': 'https://api.github.com/repos/salsita/foosball-rating',
#       'forks_url': 'https://api.github.com/repos/salsita/foosball-rating/forks',
#       'keys_url': 'https://api.github.com/repos/salsita/foosball-rating/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/salsita/foosball-rating/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/salsita/foosball-rating/teams',
#       'hooks_url': 'https://api.github.com/repos/salsita/foosball-rating/hooks',
#       'issue_events_url': 'https://api.github.com/repos/salsita/foosball-rating/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/salsita/foosball-rating/events',
#       'assignees_url': 'https://api.github.com/repos/salsita/foosball-rating/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/salsita/foosball-rating/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/salsita/foosball-rating/tags',
#       'blobs_url': 'https://api.github.com/repos/salsita/foosball-rating/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/salsita/foosball-rating/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/salsita/foosball-rating/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/salsita/foosball-rating/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/salsita/foosball-rating/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/salsita/foosball-rating/languages',
#       'stargazers_url': 'https://api.github.com/repos/salsita/foosball-rating/stargazers',
#       'contributors_url': 'https://api.github.com/repos/salsita/foosball-rating/contributors',
#       'subscribers_url': 'https://api.github.com/repos/salsita/foosball-rating/subscribers',
#       'subscription_url': 'https://api.github.com/repos/salsita/foosball-rating/subscription',
#       'commits_url': 'https://api.github.com/repos/salsita/foosball-rating/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/salsita/foosball-rating/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/salsita/foosball-rating/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/salsita/foosball-rating/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/salsita/foosball-rating/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/salsita/foosball-rating/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/salsita/foosball-rating/merges',
#       'archive_url': 'https://api.github.com/repos/salsita/foosball-rating/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/salsita/foosball-rating/downloads',
#       'issues_url': 'https://api.github.com/repos/salsita/foosball-rating/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/salsita/foosball-rating/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/salsita/foosball-rating/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/salsita/foosball-rating/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/salsita/foosball-rating/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/salsita/foosball-rating/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/salsita/foosball-rating/deployments',
#       'created_at': '2019-03-04T09:30:18Z',
#       'updated_at': '2020-02-14T16:30:50Z',
#       'pushed_at': '2020-02-27T10:17:27Z',
#       'git_url': 'git://github.com/salsita/foosball-rating.git',
#       'ssh_url': 'git@github.com:salsita/foosball-rating.git',
#       'clone_url': 'https://github.com/salsita/foosball-rating.git',
#       'svn_url': 'https://github.com/salsita/foosball-rating',
#       'homepage': 'http://foos.salsitasoft.com',
#       'size': 757,
#       'stargazers_count': 4,
#       'watchers_count': 4,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 17,
#       'license': None,
#       'forks': 0,
#       'open_issues': 17,
#       'watchers': 4,
#       'default_branch': 'master'}},
#     'base': {'label': 'salsita:master',
#      'ref': 'master',
#      'sha': '5ba8dbe0a44592eb90e36f685d53aeba6c89d436',
#      'user': {'login': 'salsita',
#       'id': 1357845,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEzNTc4NDU=',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/1357845?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/salsita',
#       'html_url': 'https://github.com/salsita',
#       'followers_url': 'https://api.github.com/users/salsita/followers',
#       'following_url': 'https://api.github.com/users/salsita/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/salsita/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/salsita/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/salsita/subscriptions',
#       'organizations_url': 'https://api.github.com/users/salsita/orgs',
#       'repos_url': 'https://api.github.com/users/salsita/repos',
#       'events_url': 'https://api.github.com/users/salsita/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/salsita/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 173714728,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNzM3MTQ3Mjg=',
#       'name': 'foosball-rating',
#       'full_name': 'salsita/foosball-rating',
#       'private': False,
#       'owner': {'login': 'salsita',
#        'id': 1357845,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEzNTc4NDU=',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/1357845?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/salsita',
#        'html_url': 'https://github.com/salsita',
#        'followers_url': 'https://api.github.com/users/salsita/followers',
#        'following_url': 'https://api.github.com/users/salsita/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/salsita/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/salsita/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/salsita/subscriptions',
#        'organizations_url': 'https://api.github.com/users/salsita/orgs',
#        'repos_url': 'https://api.github.com/users/salsita/repos',
#        'events_url': 'https://api.github.com/users/salsita/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/salsita/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/salsita/foosball-rating',
#       'description': "Keeps track of foosball player's rating based on augmented chess elo rating",
#       'fork': False,
#       'url': 'https://api.github.com/repos/salsita/foosball-rating',
#       'forks_url': 'https://api.github.com/repos/salsita/foosball-rating/forks',
#       'keys_url': 'https://api.github.com/repos/salsita/foosball-rating/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/salsita/foosball-rating/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/salsita/foosball-rating/teams',
#       'hooks_url': 'https://api.github.com/repos/salsita/foosball-rating/hooks',
#       'issue_events_url': 'https://api.github.com/repos/salsita/foosball-rating/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/salsita/foosball-rating/events',
#       'assignees_url': 'https://api.github.com/repos/salsita/foosball-rating/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/salsita/foosball-rating/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/salsita/foosball-rating/tags',
#       'blobs_url': 'https://api.github.com/repos/salsita/foosball-rating/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/salsita/foosball-rating/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/salsita/foosball-rating/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/salsita/foosball-rating/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/salsita/foosball-rating/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/salsita/foosball-rating/languages',
#       'stargazers_url': 'https://api.github.com/repos/salsita/foosball-rating/stargazers',
#       'contributors_url': 'https://api.github.com/repos/salsita/foosball-rating/contributors',
#       'subscribers_url': 'https://api.github.com/repos/salsita/foosball-rating/subscribers',
# ...
#       'name': 'test0227',
#       'full_name': 'sartest/test0227',
#       'private': False,
#       'owner': {'login': 'sartest',
#        'id': 56335241,
#        'node_id': 'MDQ6VXNlcjU2MzM1MjQx',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/56335241?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/sartest',
#        'html_url': 'https://github.com/sartest',
#        'followers_url': 'https://api.github.com/users/sartest/followers',
#        'following_url': 'https://api.github.com/users/sartest/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/sartest/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/sartest/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/sartest/subscriptions',
#        'organizations_url': 'https://api.github.com/users/sartest/orgs',
#        'repos_url': 'https://api.github.com/users/sartest/repos',
#        'events_url': 'https://api.github.com/users/sartest/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/sartest/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/sartest/test0227',
#       'description': None,
#       'fork': True,
#       'url': 'https://api.github.com/repos/sartest/test0227',
#       'forks_url': 'https://api.github.com/repos/sartest/test0227/forks',
#       'keys_url': 'https://api.github.com/repos/sartest/test0227/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/sartest/test0227/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/sartest/test0227/teams',
#       'hooks_url': 'https://api.github.com/repos/sartest/test0227/hooks',
#       'issue_events_url': 'https://api.github.com/repos/sartest/test0227/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/sartest/test0227/events',
#       'assignees_url': 'https://api.github.com/repos/sartest/test0227/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/sartest/test0227/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/sartest/test0227/tags',
#       'blobs_url': 'https://api.github.com/repos/sartest/test0227/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/sartest/test0227/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/sartest/test0227/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/sartest/test0227/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/sartest/test0227/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/sartest/test0227/languages',
#       'stargazers_url': 'https://api.github.com/repos/sartest/test0227/stargazers',
#       'contributors_url': 'https://api.github.com/repos/sartest/test0227/contributors',
#       'subscribers_url': 'https://api.github.com/repos/sartest/test0227/subscribers',
#       'subscription_url': 'https://api.github.com/repos/sartest/test0227/subscription',
#       'commits_url': 'https://api.github.com/repos/sartest/test0227/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/sartest/test0227/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/sartest/test0227/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/sartest/test0227/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/sartest/test0227/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/sartest/test0227/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/sartest/test0227/merges',
#       'archive_url': 'https://api.github.com/repos/sartest/test0227/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/sartest/test0227/downloads',
#       'issues_url': 'https://api.github.com/repos/sartest/test0227/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/sartest/test0227/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/sartest/test0227/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/sartest/test0227/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/sartest/test0227/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/sartest/test0227/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/sartest/test0227/deployments',
#       'created_at': '2020-02-27T07:18:42Z',
#       'updated_at': '2020-02-27T10:23:56Z',
#       'pushed_at': '2020-02-27T10:23:54Z',
#       'git_url': 'git://github.com/sartest/test0227.git',
#       'ssh_url': 'git@github.com:sartest/test0227.git',
#       'clone_url': 'https://github.com/sartest/test0227.git',
#       'svn_url': 'https://github.com/sartest/test0227',
#       'homepage': None,
#       'size': 10,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Java',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'shianr:master',
#      'ref': 'master',
#      'sha': 'e4d698a4373969d68fa483999eed7f8dc95a44a7',
#      'user': {'login': 'shianr',
#       'id': 28378961,
#       'node_id': 'MDQ6VXNlcjI4Mzc4OTYx',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/28378961?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/shianr',
#       'html_url': 'https://github.com/shianr',
#       'followers_url': 'https://api.github.com/users/shianr/followers',
#       'following_url': 'https://api.github.com/users/shianr/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/shianr/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/shianr/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/shianr/subscriptions',
#       'organizations_url': 'https://api.github.com/users/shianr/orgs',
#       'repos_url': 'https://api.github.com/users/shianr/repos',
#       'events_url': 'https://api.github.com/users/shianr/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/shianr/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 243452299,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNDM0NTIyOTk=',
#       'name': 'test0227',
#       'full_name': 'shianr/test0227',
#       'private': False,
#       'owner': {'login': 'shianr',
#        'id': 28378961,
#        'node_id': 'MDQ6VXNlcjI4Mzc4OTYx',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/28378961?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/shianr',
#        'html_url': 'https://github.com/shianr',
#        'followers_url': 'https://api.github.com/users/shianr/followers',
#        'following_url': 'https://api.github.com/users/shianr/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/shianr/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/shianr/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/shianr/subscriptions',
#        'organizations_url': 'https://api.github.com/users/shianr/orgs',
#        'repos_url': 'https://api.github.com/users/shianr/repos',
#        'events_url': 'https://api.github.com/users/shianr/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/shianr/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/shianr/test0227',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/shianr/test0227',
#       'forks_url': 'https://api.github.com/repos/shianr/test0227/forks',
#       'keys_url': 'https://api.github.com/repos/shianr/test0227/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/shianr/test0227/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/shianr/test0227/teams',
#       'hooks_url': 'https://api.github.com/repos/shianr/test0227/hooks',
#       'issue_events_url': 'https://api.github.com/repos/shianr/test0227/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/shianr/test0227/events',
#       'assignees_url': 'https://api.github.com/repos/shianr/test0227/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/shianr/test0227/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/shianr/test0227/tags',
#       'blobs_url': 'https://api.github.com/repos/shianr/test0227/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/shianr/test0227/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/shianr/test0227/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/shianr/test0227/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/shianr/test0227/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/shianr/test0227/languages',
#       'stargazers_url': 'https://api.github.com/repos/shianr/test0227/stargazers',
#       'contributors_url': 'https://api.github.com/repos/shianr/test0227/contributors',
#       'subscribers_url': 'https://api.github.com/repos/shianr/test0227/subscribers',
#       'subscription_url': 'https://api.github.com/repos/shianr/test0227/subscription',
#       'commits_url': 'https://api.github.com/repos/shianr/test0227/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/shianr/test0227/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/shianr/test0227/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/shianr/test0227/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/shianr/test0227/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/shianr/test0227/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/shianr/test0227/merges',
#       'archive_url': 'https://api.github.com/repos/shianr/test0227/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/shianr/test0227/downloads',
#       'issues_url': 'https://api.github.com/repos/shianr/test0227/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/shianr/test0227/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/shianr/test0227/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/shianr/test0227/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/shianr/test0227/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/shianr/test0227/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/shianr/test0227/deployments',
#       'created_at': '2020-02-27T06:56:16Z',
#       'updated_at': '2020-02-27T09:43:04Z',
#       'pushed_at': '2020-02-27T10:24:22Z',
#       'git_url': 'git://github.com/shianr/test0227.git',
#       'ssh_url': 'git@github.com:shianr/test0227.git',
#       'clone_url': 'https://github.com/shianr/test0227.git',
#       'svn_url': 'https://github.com/shianr/test0227',
#       'homepage': None,
#       'size': 9,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Java',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'forks': 1,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/shianr/test0227/pulls/2'},
#      'html': {'href': 'https://github.com/shianr/test0227/pull/2'},
#      'issue': {'href': 'https://api.github.com/repos/shianr/test0227/issues/2'},
#      'comments': {'href': 'https://api.github.com/repos/shianr/test0227/issues/2/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/shianr/test0227/pulls/2/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/shianr/test0227/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/shianr/test0227/pulls/2/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/shianr/test0227/statuses/03133af2544309fe1afddb2350b7e5242bd02106'}},
#     'author_association': 'CONTRIBUTOR',
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'shianr',
#      'id': 28378961,
#      'node_id': 'MDQ6VXNlcjI4Mzc4OTYx',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/28378961?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/shianr',
#      'html_url': 'https://github.com/shianr',
#      'followers_url': 'https://api.github.com/users/shianr/followers',
#      'following_url': 'https://api.github.com/users/shianr/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/shianr/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/shianr/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/shianr/subscriptions',
#      'organizations_url': 'https://api.github.com/users/shianr/orgs',
#      'repos_url': 'https://api.github.com/users/shianr/repos',
#      'events_url': 'https://api.github.com/users/shianr/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/shianr/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 5,
#     'additions': 1,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-02-27T10:24:22Z'},
#  {'id': '11624237371',
#   'type': 'PushEvent',
#   'actor': {'id': 50045969,
#    'login': 'XurongChi',
#    'display_login': 'XurongChi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/XurongChi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50045969?'},
#   'repo': {'id': 217843860,
#    'name': 'XurongChi/test',
#    'url': 'https://api.github.com/repos/XurongChi/test'},
#   'payload': {'push_id': 4689352433,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd6a5ff024e379f3b0fa15d69f2f440619f48d6cd',
#    'before': '41fcd06693e19a964e4f178f954bfb46b9868117',
#    'commits': [{'sha': 'd6a5ff024e379f3b0fa15d69f2f440619f48d6cd',
#      'author': {'email': '386280576@qq.com', 'name': '“XurongChi”'},
#      'message': 'capture ip',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/XurongChi/test/commits/d6a5ff024e379f3b0fa15d69f2f440619f48d6cd'}]},
#   'public': True,
#   'created_at': '2020-02-27T10:24:22Z'},
#  {'id': '11624237363',
#   'type': 'PushEvent',
#   'actor': {'id': 61533638,
#    'login': 'Anitha241991',
#    'display_login': 'Anitha241991',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Anitha241991',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61533638?'},
#   'repo': {'id': 243478556,
#    'name': 'Anitha241991/Sensor_Codes',
#    'url': 'https://api.github.com/repos/Anitha241991/Sensor_Codes'},
#   'payload': {'push_id': 4689352422,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '3d7d73d5670e78ec534c8e32a5f578690f197511',
#    'before': '8c10e6b782c421ae3cb7947ee472d441f535bfdf',
#    'commits': [{'sha': '3d7d73d5670e78ec534c8e32a5f578690f197511',
#      'author': {'email': '61533638+Anitha241991@users.noreply.github.com',
#       'name': 'Anitha241991'},
#      'message': 'Create ST.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Anitha241991/Sensor_Codes/commits/3d7d73d5670e78ec534c8e32a5f578690f197511'}]},
#   'public': True,
#   'created_at': '2020-02-27T10:24:22Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("https://cat-fact.herokuapp.com/facts", params=payload)
json.loads(r.text)
# Out:
# {'all': [{'_id': '58e008ad0aac31001185ed0c',
#    'text': "The frequency of a domestic cat's purr is the same at which muscles and bones repair themselves.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 9,
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b4912c60508220014ccfe99',
#    'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b4911940508220014ccfe94',
#    'text': 'By the time a cat is 9 years old, it will only have been awake for three years of its life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '59a60b8e6acf530020f3586e',
#    'text': 'Cat owners are 17% more likely to have a graduate degree than non cat owners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b199196ce456e001424256a',
#    'text': 'Cats can distinguish different flavors in water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '591d9b2f227c1a0020d26823',
#    'text': 'Every year, nearly four million cats are eaten in China as a delicacy.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a090aac31001185ed16',
#    'text': 'Cats make more than 100 different sounds whereas dogs make around 10.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58cafac6ffae36001108d586',
#    'text': 'Cats have fur',
#    'type': 'cat',
#    'user': {'_id': '58c86fe52341fc0011d7b151',
#     'name': {'first': 'Alex', 'last': 'Simon'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038dae8e3dbc001f719792',
#    'text': "Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475c86a99c3f00140fe4cf',
#    'text': "The Manx hails from the Isle of Man in the Irish Sea, and many Manx are tailless, a condition believed to have been caused by a dominant genetic mutation that spread among the island's cat population.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c489117e4f6130014c987b9',
#    'text': 'Leonardo da Vinci created a series of drawings titled "Study of Cat Movements and Positions", which consists of more than twenty drawings of cats and lions lying a sleep, sitting, playing, and fighting.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60982ce549020014533033',
#    'text': 'The Chartreux is distinguished by a woolly blue-grey coat, a robust body poised over small paws, and full cheeks with a mouth that always appear to be smiling.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609852e549020014533036',
#    'text': "While Chartreux cats aren't very vocal, they are sociable and communicate through eye contact and body language.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60999ae549020014533038',
#    'text': 'Cats love playing with yarn, ribbons, and fishing-rode style toys. However, cats should not be left alone with anything that they could get tangled in.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a02e549020014533039',
#    'text': "All Scottish Folds descended from Susie, a white barn cat discovered in Scotland in the early 1960s. Susie sported the breed's folded ears – the result of a genetic mutation – and passed on the trait through breeding.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a90e54902001453303a',
#    'text': 'Mark Twain was undeniably an ailurophile. He had up to 19 cats at one time and gave them such memorable names as Beelzebub, Buffalo Bill, and Soapy Sal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c35cc2d7a200140f67ea',
#    'text': 'If you really want to treat your cat, get some lactose-free milk at the grocery store and offer some to the kitty.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c47dc2d7a200140f67ee',
#    'text': 'Abraham Lincoln, being the ailurophile that he was, once rescued three stray kittens and ensured that they were fed and found homes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c4eec2d7a200140f67ef',
#    'text': 'The Sphynx was originally known as the Canadian Hairless Cat. The breed originated in Toronto, and was renamed to Sphynx, a nod to the famous limestone sculpture in the Egyptian Desert.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c6a104fc2d7a200140f699f',
#    'text': 'A cat’s spine can rotate more than the spines of most other animals, and their vertebrae have a special, flexible, elastic cushioning on the disks, which gives it even more flexibility.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c72d9b651021f001415f00c',
#    'text': 'Cats have been domesticated for around 4,000 years. While they were once valued for their hunting abilities, they are now valued for their companionship and loving behavior.',
#    'type': 'cat',
#    'user': {'_id': '5c6fd96df4256a001498a73f',
#     'name': {'first': 'Hedvig', 'last': 'Annersten'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c72dbd851021f001415f010',
#    'text': 'The most popular pedigreed cat in North America is the Persian cat, followed by the Main Coon and the Siamese cat.',
#    'type': 'cat',
#    'user': {'_id': '5c72dbb751021f001415f00f',
#     'name': {'first': 'Hedvig', 'last': 'Annersten'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38afd60f1c57001592f127',
#    'type': 'cat',
#    'text': 'In the early 1980s, a Chinchilla Persian cat named Jemari Sanquist mated with a Lilac Burmese named Bambino Lilac Fabergé, producing the Burmilla breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0310f1c57001592f128',
#    'type': 'cat',
#    'text': 'Scratching allows a cat to shed the outer layers of her claws, mark her territory, and stretch her body. Rather than discouraging the scratching behavior altogether, try redirecting your cat to a few scratching posts placed strategically around your home.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0c40f1c57001592f129',
#    'type': 'cat',
#    'text': 'The elegant Balinese is a longhaired variety of the Siamese, and like the Siamese, this stunning breed is sociable and intelligent. The breed was named for the grace of the dancers on the island of Bali in Indonesia.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b16c0f1c57001592f12b',
#    'type': 'cat',
#    'text': 'A large number of cats inhabit the Largo di Torre Argentina, an ancient Roman temple site near where Caesar was killed. Local volunteers care for the cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2270f1c57001592f12d',
#    'type': 'cat',
#    'text': 'Among the British government officials who keep things running smoothly at 10 Downing Street is Larry, a cat that holds the distinguished position of Chief Mouser. Larry\'s duties, according to the U.K. government, include "greeting guests", "testing antique furniture for napping quality", and "contemplating a solution to the mouse occupancy of the house.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b27b0f1c57001592f12f',
#    'type': 'cat',
#    'text': 'The Norwegian Forest Cat is called "skogcatt" in its homeland of Norway and plays a role in the Norwegian fairy tales and legends.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b29f0f1c57001592f130',
#    'type': 'cat',
#    'text': 'The Abyssinian, the Siamese, and the American Shorthair were crossbred to produce the Ocicat breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6280f1c57001592f133',
#    'type': 'cat',
#    'text': 'Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'type': 'cat',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'type': 'cat',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'type': 'cat',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5de780600013130015a3ccaf',
#    'type': 'cat',
#    'text': 'About one in two cats respond to catnip, and only develop a sensitivity to it at around 3 to 6 months of age.',
# ...
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c409c2d7a200140f67ec',
#    'text': 'Cats can have three litters a year, or approximately 12 kittens.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c35531e8e0b8d00148d45e8',
#    'text': "If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c471b30a99c3f00140fe4c5',
#    'text': 'The collective noun for kittens is a "kindle".',
#    'type': 'cat',
#    'user': {'_id': '5c471b15a99c3f00140fe4c4',
#     'name': {'first': 'Beth', 'last': 'Rothwell'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609945e549020014533037',
#    'text': 'Do you ever wake up in the middle of the night and find your cat sleeping on your head? Cat behavioral experts believe that cats are drawn to the warmth and the familiar scent of the owner. Resting on your head also keeps kitty safe from your arms and legs if you toss and turn through the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c7408a14dd87d001490f02b',
#    'text': "The cheetah is the only cat that doesn't have retractable claws.",
#    'type': 'cat',
#    'user': {'_id': '5c72e94751021f001415f012',
#     'name': {'first': 'Tests', 'last': 'HiQ'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c75f56272681400147b988a',
#    'text': 'There are only two escalators in the state of Wyoming.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c84248f731a60001540a193',
#    'text': 'When a cat lifts its butt in the air when scratched, it is a sign that your feline is giving your pats an A+. However, if you have a female kitty who hasn\'t been spayed, "elevator butt" could be a sign that she\'s ready to mate. The proper name for this stance is lordosis, and cats adopt it when they\'re in heat.',
#    'type': 'cat',
#    'user': {'_id': '5c7da4bd70008708fb17c88f',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c87d03dec1e5c0aa37e0a6b',
#    'type': 'cat',
#    'text': 'On October 24, 1963, a tuxedo cat named Félicette entered outer space aboard a French Véronique AG1 rocket and made feline history. Félicette returned from the 15-minute trip in once piece and earned the praise of French scientists, who said she made "a valuable contribution to research.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd42b77cfdf230015bd7a45',
#    'text': 'Cats can sense distress from a human being.',
#    'type': 'cat',
#    'user': {'_id': '5cd42b40cfdf230015bd7a44',
#     'name': {'first': 'Chloe', 'last': 'Simmons'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd86b0e1dc6d50015ec2f08',
#    'text': 'Norwegian Forest Cats are usually very people friendly.',
#    'type': 'cat',
#    'user': {'_id': '5cd86adb1dc6d50015ec2f07',
#     'name': {'first': 'Shay', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1d40f1c57001592f12c',
#    'type': 'cat',
#    'text': "During the heat of the summer, set out an extra bowl of water and place ice cubes in it to keep it cold and refreshing. Cats love to lie on cool surfaces when it's hot—if you don't have an tile in your home, consider buying a few ceramic tiles from a home improvement store for your cat to rest on.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2510f1c57001592f12e',
#    'type': 'cat',
#    'text': 'Courgars are the largest wild cats that can purr.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to 14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5e10d7841c78ab0015bc5b15',
#    'type': 'cat',
#    'text': 'Some cats do not eat fish.',
#    'user': {'_id': '5e10d6e51c78ab0015bc5b14',
#     'name': {'first': 'Max', 'last': 'Bilohatnyuk'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e19da391fd6150015fa7356',
#    'type': 'cat',
#    'text': '"Cats can hear the ultrasonic noises that rodents and dolphins make to communicate.".',
#    'user': {'_id': '5e19d99e1fd6150015fa7353',
#     'name': {'first': 'Crystal Gale', 'last': 'Scott'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e1efba858449a0015ce4783',
#    'type': 'cat',
#    'text': '"A house cat is faster than Usain Bolt.".',
#    'user': {'_id': '5e1efb5958449a0015ce4781',
#     'name': {'first': 'oyaji', 'last': '55'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e239999dc76630015d4c5e2',
#    'type': 'cat',
#    'text': 'Cats see only on blue and yellow.',
#    'user': {'_id': '5e239963dc76630015d4c5e1',
#     'name': {'first': 'Eduardo', 'last': 'P. Gomez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e27232ec71d0900152d8518',
#    'type': 'cat',
#    'text': 'Cats are dumb.',
#    'user': {'_id': '5e272323c71d0900152d8517',
#     'name': {'first': 'Andrew', 'last': 'Steele'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e2f9f1ade397c00152dd552',
#    'type': 'cat',
#    'text': 'Cat.',
#    'user': {'_id': '5e2f9f0ede397c00152dd551',
#     'name': {'first': 'bah', 'last': 'godam99'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e2f9f23de397c00152dd553',
#    'type': 'cat',
#    'text': 'Sleep.',
#    'user': {'_id': '5e2f9f0ede397c00152dd551',
#     'name': {'first': 'bah', 'last': 'godam99'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e3382ccd7ac48001509e153',
#    'type': 'cat',
#    'text': 'Cat is an animal.',
#    'user': {'_id': '5e3381f3d7ac48001509e151',
#     'name': {'first': 'Dicka', 'last': 'Ismaji'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e344e7acd8efb0015ae3055',
#    'type': 'cat',
#    'text': 'Cat live, on average, for about 7-8 years.',
#    'user': {'_id': '5e344e3ccd8efb0015ae3054',
#     'name': {'first': 'RYAN', 'last': 'STULTZ'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e3534d8cd8efb0015ae305c',
#    'type': 'cat',
#    'text': 'Hi.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e35436d11559000151bf453',
#    'type': 'cat',
#    'text': '123.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e355bf411559000151bf454',
#    'type': 'cat',
#    'text': 'Fgf.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e380ea32035630015618254',
#    'type': 'cat',
#    'text': 'Asd.',
#    'user': {'_id': '5e380e9b2035630015618253',
#     'name': {'first': 'dm', 'last': 'max'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e56fdf375991a0015429ffc',
#    'type': 'cat',
#    'text': 'Bbb.',
#    'user': {'_id': '5e56fddd75991a0015429ffb',
#     'name': {'first': 'Cristian', 'last': 'Salcedo'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e353507cd8efb0015ae305d',
#    'type': 'cat',
#    'text': 'Test.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e4c4e10a38ae60015b04a7e',
#    'type': 'cat',
#    'text': "Cats think humans have night vision too, so when we step on their tail in the middle of the night, they think it's on purpose.",
#    'user': {'_id': '5e4c4dc5a38ae60015b04a7d',
#     'name': {'first': 'Nathaniel J', 'last': 'McDermott'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e546a054e83e80015a0e320',
#    'type': 'cat',
#    'text': "Contrary to popular belief, some cats actually don't mind water. The hairless Sphynx cat enjoys it, especially if it is warm.",
#    'user': {'_id': '5e54675a4e83e80015a0e313',
#     'name': {'first': "L'hibou", 'last': 'Ambigu'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}

# %%
r = requests.post('https://cat-fact.herokuapp.com/facts', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'message': 'Sign in first'}
